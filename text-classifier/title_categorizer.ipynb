# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('torob_train.csv')
test = pd.read_csv('torob_test.csv')

# %%
train.head()
# Out:
#                                                name1 name2  cat_id
# 0                   کاپشن کوهنوردی پر سنگین نورث فیس   NaN       0
# 1                       پالتو خزدار مردانه مارک اصلی   NaN       0
# 2                              کاپشن مردانه مدل Bako   NaN       0
# 3  کاپشن سالامون salomon پارچه گورتکس کره ای اعلا...   NaN       0
# 4                  کاپشن‌‌‌ نظامی‌‌‌ آمریکایی‌‌‌ سبز   NaN       0

# %%
test.head()
# Out:
#                                            name1 name2
# 0                         بگ پارچه ای دو رنگ چاپ   NaN
# 1  بادگیر کلاهدار ورزشی فرانسه France windrunner   NaN
# 2                              ساعت دیواری هندسی   NaN
# 3                      ساک ورزشی Nike مدل N20627   NaN
# 4                                      ساعت فلزی   NaN

# %%
print("Train set size:", len(train))
print("Test set size:", len(test))
print("Fraction:", len(train)/len(test))
# Out:
# Train set size: 8822
# Test set size: 1201
# Fraction: 7.345545378850957

# %%
# !pip install DadmaTools
# Out:
# Collecting DadmaTools
#   Downloading dadmatools-2.0.1-py3-none-any.whl (887 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 kB 12.1 MB/s eta 0:00:00
# Collecting bpemb>=0.3.3 (from DadmaTools)
#   Downloading bpemb-0.3.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (3.8.1)
# Requirement already satisfied: folium>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (0.14.0)
# Requirement already satisfied: spacy>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (3.7.4)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (2.1.0+cu121)
# Requirement already satisfied: transformers>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (4.38.2)
# Requirement already satisfied: h5py>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (3.9.0)
# Collecting Deprecated==1.2.6 (from DadmaTools)
#   Downloading Deprecated-1.2.6-py2.py3-none-any.whl (8.1 kB)
# Requirement already satisfied: hyperopt>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (0.2.7)
# Collecting pyconll>=3.1.0 (from DadmaTools)
#   Downloading pyconll-3.2.0-py3-none-any.whl (27 kB)
# Collecting pytorch-transformers>=1.1.0 (from DadmaTools)
#   Downloading pytorch_transformers-1.2.0-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.4/176.4 kB 15.6 MB/s eta 0:00:00
# Collecting segtok>=1.5.7 (from DadmaTools)
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: tabulate>=0.8.6 in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (0.9.0)
# Collecting supar==1.1.2 (from DadmaTools)
#   Downloading supar-1.1.2-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: gensim>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (4.3.2)
# Collecting conllu (from DadmaTools)
#   Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: gdown>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (4.7.3)
# Collecting py7zr>=0.17.2 (from DadmaTools)
#   Downloading py7zr-0.21.0-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 6.7 MB/s eta 0:00:00
# Collecting html2text (from DadmaTools)
#   Downloading html2text-2024.2.26.tar.gz (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from DadmaTools)
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (1.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (1.25.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (2.31.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (4.66.2)
# Collecting langid==1.1.6 (from DadmaTools)
#   Downloading langid-1.1.6.tar.gz (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 25.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (3.13.1)
# Requirement already satisfied: tokenizers>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (0.15.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (2023.12.25)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (23.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from DadmaTools) (0.1.99)
# Collecting sacremoses (from DadmaTools)
#   Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 38.7 MB/s eta 0:00:00
# Collecting fasttext (from DadmaTools)
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 9.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting kenlm (from DadmaTools)
#   Downloading kenlm-0.2.0.tar.gz (427 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.4/427.4 kB 27.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated==1.2.6->DadmaTools) (1.14.1)
# Collecting stanza (from supar==1.1.2->DadmaTools)
#   Downloading stanza-1.8.1-py3-none-any.whl (970 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 970.4/970.4 kB 33.8 MB/s eta 0:00:00
# Collecting dill (from supar==1.1.2->DadmaTools)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium>=0.2.1->DadmaTools) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium>=0.2.1->DadmaTools) (3.1.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown>=4.3.1->DadmaTools) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=4.3.1->DadmaTools) (4.12.3)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim>=3.6.0->DadmaTools) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=3.6.0->DadmaTools) (6.4.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.5->DadmaTools) (3.2.1)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.5->DadmaTools) (0.18.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.5->DadmaTools) (2.2.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.5->DadmaTools) (0.10.9.7)
# Collecting texttable (from py7zr>=0.17.2->DadmaTools)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting pycryptodomex>=3.16.0 (from py7zr>=0.17.2->DadmaTools)
#   Downloading pycryptodomex-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 45.9 MB/s eta 0:00:00
# Collecting pyzstd>=0.15.9 (from py7zr>=0.17.2->DadmaTools)
#   Downloading pyzstd-0.15.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 2.0 MB/s eta 0:00:00
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr>=0.17.2->DadmaTools)
#   Downloading pyppmd-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.9/138.9 kB 18.2 MB/s eta 0:00:00
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr>=0.17.2->DadmaTools)
#   Downloading pybcj-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 7.5 MB/s eta 0:00:00
# Collecting multivolumefile>=0.2.3 (from py7zr>=0.17.2->DadmaTools)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr>=0.17.2->DadmaTools)
#   Downloading inflate64-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 13.6 MB/s eta 0:00:00
# Collecting brotli>=1.1.0 (from py7zr>=0.17.2->DadmaTools)
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 58.3 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from py7zr>=0.17.2->DadmaTools) (5.9.5)
# Collecting boto3 (from pytorch-transformers>=1.1.0->DadmaTools)
#   Downloading boto3-1.34.59-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->DadmaTools) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->DadmaTools) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->DadmaTools) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->DadmaTools) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->DadmaTools) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->DadmaTools) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->DadmaTools) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->DadmaTools) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->DadmaTools) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->DadmaTools) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->DadmaTools) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->DadmaTools) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->DadmaTools) (0.9.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->DadmaTools) (2.6.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->DadmaTools) (67.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.0->DadmaTools) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->DadmaTools) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->DadmaTools) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->DadmaTools) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->DadmaTools) (2024.2.2)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.7.0->DadmaTools) (0.20.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->DadmaTools) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->DadmaTools) (1.12)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->DadmaTools) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->DadmaTools) (2.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.9.1->DadmaTools) (6.0.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.9.1->DadmaTools) (0.4.2)
# Collecting pybind11>=2.2 (from fasttext->DadmaTools)
#   Using cached pybind11-2.11.1-py3-none-any.whl (227 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->DadmaTools) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium>=0.2.1->DadmaTools) (2.1.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0.0->DadmaTools) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0.0->DadmaTools) (2.16.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=3.0.0->DadmaTools) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=3.0.0->DadmaTools) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy>=3.0.0->DadmaTools) (0.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=4.3.1->DadmaTools) (2.5)
# Collecting botocore<1.35.0,>=1.34.59 (from boto3->pytorch-transformers>=1.1.0->DadmaTools)
#   Downloading botocore-1.34.59-py3-none-any.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 73.5 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->pytorch-transformers>=1.1.0->DadmaTools)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3->pytorch-transformers>=1.1.0->DadmaTools)
#   Downloading s3transfer-0.10.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests->DadmaTools) (1.7.1)
# Collecting emoji (from stanza->supar==1.1.2->DadmaTools)
#   Downloading emoji-2.10.1-py2.py3-none-any.whl (421 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 44.5 MB/s eta 0:00:00
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from stanza->supar==1.1.2->DadmaTools) (0.10.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7.1->DadmaTools) (1.3.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.59->boto3->pytorch-transformers>=1.1.0->DadmaTools) (2.8.2)
# Building wheels for collected packages: langid, fasttext, html2text, kenlm
#   Building wheel for langid (setup.py) ... done
#   Created wheel for langid: filename=langid-1.1.6-py3-none-any.whl size=1941172 sha256=219761b5b92209b73ebc14bd542215e98bcab18adbb16644cd4343c57fd4b981
#   Stored in directory: /root/.cache/pip/wheels/23/c8/c6/eed80894918490a175677414d40bd7c851413bbe03d4856c3c
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4199773 sha256=b70edb647ec4a181096d1cb4afc9d4b6f71f8c4f7ac28c7213265094e5ab3c0b
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
#   Building wheel for html2text (setup.py) ... done
#   Created wheel for html2text: filename=html2text-2024.2.26-py3-none-any.whl size=33110 sha256=a27244980e6ead0c27313347b98855c5e357a19adf7fb135d4e03bb42b70f21d
#   Stored in directory: /root/.cache/pip/wheels/f3/96/6d/a7eba8f80d31cbd188a2787b81514d82fc5ae6943c44777659
#   Building wheel for kenlm (pyproject.toml) ... done
#   Created wheel for kenlm: filename=kenlm-0.2.0-cp310-cp310-linux_x86_64.whl size=3184474 sha256=9183fdfa28cf33fc78a42135e593327c40aab0437d181a238b9fc9b35b2459cd
#   Stored in directory: /root/.cache/pip/wheels/fd/80/e0/18f4148e863fb137bd87e21ee2bf423b81b3ed6989dab95135
# Successfully built langid fasttext html2text kenlm
# Installing collected packages: tf-estimator-nightly, texttable, kenlm, brotli, segtok, sacremoses, pyzstd, pyppmd, pycryptodomex, pyconll, pybind11, pybcj, multivolumefile, langid, jmespath, inflate64, html2text, emoji, dill, Deprecated, conllu, py7zr, fasttext, botocore, stanza, s3transfer, bpemb, boto3, supar, pytorch-transformers, DadmaTools
# Successfully installed DadmaTools-2.0.1 Deprecated-1.2.6 boto3-1.34.59 botocore-1.34.59 bpemb-0.3.4 brotli-1.1.0 conllu-4.5.3 dill-0.3.8 emoji-2.10.1 fasttext-0.9.2 html2text-2024.2.26 inflate64-1.0.0 jmespath-1.0.1 kenlm-0.2.0 langid-1.1.6 multivolumefile-0.2.3 py7zr-0.21.0 pybcj-1.0.2 pybind11-2.11.1 pyconll-3.2.0 pycryptodomex-3.20.0 pyppmd-1.1.0 pytorch-transformers-1.2.0 pyzstd-0.15.9 s3transfer-0.10.0 sacremoses-0.1.1 segtok-1.5.11 stanza-1.8.1 supar-1.1.2 texttable-1.7.0 tf-estimator-nightly-2.8.0.dev2021122109

# %%
import dadmatools.pipeline.language as language

pips = 'tok, lem'
nlp = language.Pipeline(pips)
# Out:
# Downloading file cache/dadmatools/fa_tokenizer.pt: : 639kB [00:00, 707kB/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# persian.vocabs.json:   0%|          | 0.00/6.10k [00:00<?, ?B/s]
# persian_lemmatizer.pt:   0%|          | 0.00/2.89M [00:00<?, ?B/s]
# persian_mwt_expander.pt:   0%|          | 0.00/589k [00:00<?, ?B/s]
# persian.tagger.mdl:   0%|          | 0.00/17.0M [00:00<?, ?B/s]
# persian.tokenizer.mdl:   0%|          | 0.00/9.51M [00:00<?, ?B/s]
# Loading pretrained XLM-Roberta, this may take a while...
# Downloading:   0%|          | 0.00/512 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Model fa_tokenizer exists in cache/dadmatools/fa_tokenizer.pt
# Loading tokenizer for persian
# Loading tagger for persian
# Loading multi-word expander for persian
# Loading lemmatizer for persian
# ==================================================
# Active language: persian
# ==================================================

# %%
from dadmatools.normalizer import Normalizer

normalizer = Normalizer(
    full_cleaning=False,
    unify_chars=True,
    refine_punc_spacing=True,
    remove_extra_space=True,
    remove_puncs=True,
    remove_html=False,
    remove_stop_word=False,
    replace_email_with="",
    replace_number_with="",
    replace_url_with="",
    replace_mobile_number_with="",
    replace_emoji_with="",
    replace_home_number_with=""
)

# %%
train['normalized_text'] = train['name1'].apply(normalizer.normalize)
test['normalized_text'] = test['name1'].apply(normalizer.normalize)

# %%
train.head()
# Out:
#                                                name1 name2  cat_id  \
# 0                   کاپشن کوهنوردی پر سنگین نورث فیس   NaN       0
# 1                       پالتو خزدار مردانه مارک اصلی   NaN       0
# 2                              کاپشن مردانه مدل Bako   NaN       0
# 3  کاپشن سالامون salomon پارچه گورتکس کره ای اعلا...   NaN       0
# 4                  کاپشن‌‌‌ نظامی‌‌‌ آمریکایی‌‌‌ سبز   NaN       0
#
#                                      normalized_text
# 0                   کاپشن کوهنوردی پر سنگین نورث فیس
# 1                       پالتو خزدار مردانه مارک اصلی
# 2                              کاپشن مردانه مدل Bako
# 3  کاپشن سالامون salomon پارچه گورتکس کره ای اعلا...
# 4                  کاپشن‌‌‌ نظامی‌‌‌ آمریکایی‌‌‌ سبز

# %%
import nltk

from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
train['tokens'] = train['normalized_text'].apply(lambda x: word_tokenize(x))
test['tokens'] = test['normalized_text'].apply(lambda x: word_tokenize(x))

# %%
import re
train['tokens'] = train['tokens'].apply(lambda x: [re.sub(r'\d+', '', token) for token in x])
test['tokens'] = test['tokens'].apply(lambda x: [re.sub(r'\d+', '', token) for token in x])

# %%
train['tokens'] = train['tokens'].apply(lambda x: [token for token in x if len(token) >= 3])
test['tokens'] = test['tokens'].apply(lambda x: [token for token in x if len(token) >= 3])

# %%
train['tokens'] = train['tokens'].apply(lambda x: [token.lower() for token in x])
test['tokens'] = test['tokens'].apply(lambda x: [token.lower() for token in x])

# %%
train.head()
# Out:
#                                                name1 name2  cat_id  \
# 0                   کاپشن کوهنوردی پر سنگین نورث فیس   NaN       0
# 1                       پالتو خزدار مردانه مارک اصلی   NaN       0
# 2                              کاپشن مردانه مدل Bako   NaN       0
# 3  کاپشن سالامون salomon پارچه گورتکس کره ای اعلا...   NaN       0
# 4                  کاپشن‌‌‌ نظامی‌‌‌ آمریکایی‌‌‌ سبز   NaN       0
#
#                                      normalized_text  \
# 0                   کاپشن کوهنوردی پر سنگین نورث فیس
# 1                       پالتو خزدار مردانه مارک اصلی
# 2                              کاپشن مردانه مدل Bako
# 3  کاپشن سالامون salomon پارچه گورتکس کره ای اعلا...
# 4                  کاپشن‌‌‌ نظامی‌‌‌ آمریکایی‌‌‌ سبز
#
#                                               tokens
# 0                [کاپشن, کوهنوردی, سنگین, نورث, فیس]
# 1                 [پالتو, خزدار, مردانه, مارک, اصلی]
# 2                         [کاپشن, مردانه, مدل, bako]
# 3  [کاپشن, سالامون, salomon, پارچه, گورتکس, کره, ...
# 4             [کاپشن‌‌‌, نظامی‌‌‌, آمریکایی‌‌‌, سبز]

# %%
train['normalized_text'] = train['tokens'].apply(lambda x: ' '.join(x))
test['normalized_text'] = test['tokens'].apply(lambda x: ' '.join(x))

# %%
train.head()
# Out:
#                                                name1 name2  cat_id  \
# 0                   کاپشن کوهنوردی پر سنگین نورث فیس   NaN       0
# 1                       پالتو خزدار مردانه مارک اصلی   NaN       0
# 2                              کاپشن مردانه مدل Bako   NaN       0
# 3  کاپشن سالامون salomon پارچه گورتکس کره ای اعلا...   NaN       0
# 4                  کاپشن‌‌‌ نظامی‌‌‌ آمریکایی‌‌‌ سبز   NaN       0
#
#                                      normalized_text  \
# 0                      کاپشن کوهنوردی سنگین نورث فیس
# 1                       پالتو خزدار مردانه مارک اصلی
# 2                              کاپشن مردانه مدل bako
# 3  کاپشن سالامون salomon پارچه گورتکس کره اعلا با...
# 4                  کاپشن‌‌‌ نظامی‌‌‌ آمریکایی‌‌‌ سبز
#
#                                               tokens
# 0                [کاپشن, کوهنوردی, سنگین, نورث, فیس]
# 1                 [پالتو, خزدار, مردانه, مارک, اصلی]
# 2                         [کاپشن, مردانه, مدل, bako]
# 3  [کاپشن, سالامون, salomon, پارچه, گورتکس, کره, ...
# 4             [کاپشن‌‌‌, نظامی‌‌‌, آمریکایی‌‌‌, سبز]

# %%
train.isnull().sum()
# Out:
# name1                 0
# name2              8226
# cat_id                0
# normalized_text       8
# tokens                0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# name1                 0
# name2              1113
# normalized_text       2
# tokens                0
# dtype: int64

# %%
train['normalized_text'] = train['normalized_text'].fillna(train['name1'])
test['normalized_text'] = test['normalized_text'].fillna(test['name1'])

# %%
train.isnull().sum()
# Out:
# name1                 0
# name2              8226
# cat_id                0
# normalized_text       0
# tokens                0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# name1                 0
# name2              1113
# normalized_text       0
# tokens                0
# dtype: int64

# %%
train.to_csv('train_preprocessed.csv', index=False)
test.to_csv('test_preprocessed.csv', index=False)

# %%
train = pd.read_csv('train_preprocessed.csv')
test = pd.read_csv('test_preprocessed.csv')

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(train['normalized_text'], train['cat_id'], test_size=0.12, random_state=42)
X_test = test['normalized_text'].to_numpy()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train)
X_val_tfidf = vectorizer.transform(X_val)
X_test_tfidf = vectorizer.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(X_train_tfidf, y_train)

train_acc = clf.score(X_train_tfidf, y_train)
val_acc = clf.score(X_val_tfidf, y_val)
print(f'train acc: {train_acc}, validation acc: {val_acc}')
# Out:
# train acc: 0.9603246167718665, validation acc: 0.9263456090651558

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=42).fit(X_train_tfidf, y_train)

train_acc = clf.score(X_train_tfidf, y_train)
val_acc = clf.score(X_val_tfidf, y_val)
print(f'train acc: {train_acc}, validation acc: {val_acc}')
# Out:
# train acc: 0.9765554553651938, validation acc: 0.959395656279509

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC(random_state=42).fit(X_train_tfidf, y_train)

train_acc = clf.score(X_train_tfidf, y_train)
val_acc = clf.score(X_val_tfidf, y_val)
print(f'train acc: {train_acc}, validation acc: {val_acc}')
# Out:
# train acc: 0.9929151101378333, validation acc: 0.9612842304060434

# %%
# !pip install keras --upgrade
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting keras
#   Downloading keras-3.0.5-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Collecting namex (from keras)
#   Downloading namex-0.0.7-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.9.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras) (0.1.8)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Installing collected packages: namex, keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.0.5 which is incompatible.
# Successfully installed keras-3.0.5 namex-0.0.7

# %%
import keras

vectorizer = keras.layers.TextVectorization(output_mode='tf_idf', ngrams=2, max_tokens=4096, pad_to_max_tokens=True)
vectorizer.adapt(X_train)

# %%
vocab = vectorizer.get_vocabulary()
vocab_size = vectorizer.vocabulary_size()
print(vocab_size)
# Out:
# 4096

# %%
model = keras.Sequential([
    vectorizer,
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(1028, activation='relu'),
    keras.layers.Dropout(0.4),
    keras.layers.Dense(11, activation='softmax')
])

# %%
model.compile(
    loss = keras.losses.categorical_crossentropy,
    optimizer = keras.optimizers.SGD(learning_rate=0.01),
    metrics = ['accuracy']
)

# %%
y_train_cat = keras.utils.to_categorical(y_train, 11)
y_val_cat = keras.utils.to_categorical(y_val, 11)

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)

history = model.fit(
    X_train, y_train_cat,
    epochs=50,
    batch_size=64,
    validation_data=(X_val, y_val_cat),
    callbacks=[early_stopping_cb]
)
# Out:
# Epoch 1/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.1144 - loss: 2.4114 - val_accuracy: 0.2748 - val_loss: 2.3138
# Epoch 2/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2041 - loss: 2.3205 - val_accuracy: 0.3985 - val_loss: 2.2135
# Epoch 3/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3026 - loss: 2.2200 - val_accuracy: 0.4476 - val_loss: 2.0573
# Epoch 4/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3940 - loss: 2.0624 - val_accuracy: 0.6619 - val_loss: 1.7808
# Epoch 5/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5327 - loss: 1.8025 - val_accuracy: 0.6704 - val_loss: 1.4641
# Epoch 6/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6453 - loss: 1.4849 - val_accuracy: 0.8074 - val_loss: 1.0492
# Epoch 7/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7269 - loss: 1.1504 - val_accuracy: 0.8395 - val_loss: 0.8259
# Epoch 8/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7816 - loss: 0.9235 - val_accuracy: 0.7554 - val_loss: 0.8654
# Epoch 9/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8235 - loss: 0.7421 - val_accuracy: 0.8895 - val_loss: 0.4619
# Epoch 10/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8545 - loss: 0.5723 - val_accuracy: 0.9084 - val_loss: 0.3398
# Epoch 11/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8631 - loss: 0.5352 - val_accuracy: 0.9056 - val_loss: 0.3775
# Epoch 12/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8852 - loss: 0.4520 - val_accuracy: 0.8291 - val_loss: 0.5440
# Epoch 13/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8832 - loss: 0.4297 - val_accuracy: 0.8848 - val_loss: 0.3436
# Epoch 14/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9031 - loss: 0.3602 - val_accuracy: 0.9037 - val_loss: 0.3076
# Epoch 15/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8785 - loss: 0.4855 - val_accuracy: 0.9226 - val_loss: 0.2461
# Epoch 16/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8971 - loss: 0.3869 - val_accuracy: 0.8678 - val_loss: 0.4825
# Epoch 17/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9051 - loss: 0.3338 - val_accuracy: 0.9301 - val_loss: 0.2189
# Epoch 18/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9026 - loss: 0.3274 - val_accuracy: 0.9282 - val_loss: 0.2329
# Epoch 19/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9142 - loss: 0.2992 - val_accuracy: 0.9405 - val_loss: 0.1836
# Epoch 20/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9191 - loss: 0.2847 - val_accuracy: 0.9424 - val_loss: 0.1696
# Epoch 21/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9234 - loss: 0.2423 - val_accuracy: 0.8754 - val_loss: 0.4601
# Epoch 22/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8960 - loss: 0.3562 - val_accuracy: 0.9377 - val_loss: 0.2092
# Epoch 23/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9251 - loss: 0.2971 - val_accuracy: 0.9433 - val_loss: 0.1701
# Epoch 24/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9374 - loss: 0.1988 - val_accuracy: 0.8933 - val_loss: 0.4299
# Epoch 25/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9337 - loss: 0.2263 - val_accuracy: 0.9462 - val_loss: 0.1537
# Epoch 26/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9358 - loss: 0.1963 - val_accuracy: 0.8933 - val_loss: 0.3740
# Epoch 27/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9256 - loss: 0.2459 - val_accuracy: 0.8829 - val_loss: 0.4479
# Epoch 28/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9377 - loss: 0.2179 - val_accuracy: 0.9462 - val_loss: 0.1594
# Epoch 29/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9333 - loss: 0.2531 - val_accuracy: 0.9415 - val_loss: 0.1751
# Epoch 30/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9468 - loss: 0.1769 - val_accuracy: 0.8782 - val_loss: 0.3747
# Epoch 31/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9438 - loss: 0.2054 - val_accuracy: 0.9500 - val_loss: 0.1632
# Epoch 32/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9485 - loss: 0.1783 - val_accuracy: 0.9197 - val_loss: 0.2553
# Epoch 33/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9428 - loss: 0.2129 - val_accuracy: 0.9377 - val_loss: 0.1824
# Epoch 34/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9476 - loss: 0.1653 - val_accuracy: 0.9424 - val_loss: 0.1794
# Epoch 35/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9569 - loss: 0.1428 - val_accuracy: 0.9471 - val_loss: 0.1517
# Epoch 36/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9601 - loss: 0.1313 - val_accuracy: 0.9263 - val_loss: 0.2376
# Epoch 37/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9504 - loss: 0.1756 - val_accuracy: 0.9509 - val_loss: 0.1558
# Epoch 38/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9532 - loss: 0.1499 - val_accuracy: 0.9339 - val_loss: 0.1692
# Epoch 39/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9536 - loss: 0.1463 - val_accuracy: 0.9330 - val_loss: 0.1916
# Epoch 40/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9459 - loss: 0.1670 - val_accuracy: 0.9500 - val_loss: 0.1460
# Epoch 41/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9503 - loss: 0.1669 - val_accuracy: 0.9509 - val_loss: 0.1577
# Epoch 42/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9618 - loss: 0.1449 - val_accuracy: 0.9537 - val_loss: 0.1444
# Epoch 43/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9526 - loss: 0.1524 - val_accuracy: 0.9386 - val_loss: 0.2095
# Epoch 44/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9588 - loss: 0.1392 - val_accuracy: 0.9263 - val_loss: 0.2109
# Epoch 45/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9642 - loss: 0.1080 - val_accuracy: 0.9424 - val_loss: 0.1756
# Epoch 46/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9585 - loss: 0.1222 - val_accuracy: 0.9330 - val_loss: 0.2029
# Epoch 47/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9547 - loss: 0.1510 - val_accuracy: 0.8187 - val_loss: 0.9659
# Epoch 48/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9468 - loss: 0.1696 - val_accuracy: 0.9226 - val_loss: 0.2600
# Epoch 49/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9631 - loss: 0.1184 - val_accuracy: 0.6440 - val_loss: 3.1080
# Epoch 50/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9385 - loss: 0.3208 - val_accuracy: 0.9433 - val_loss: 0.1746

# %%
train_acc = model.evaluate(X_train, y_train_cat)[1]
val_acc = model.evaluate(X_val, y_val_cat)[1]
print(f'train acc: {train_acc}, validation acc: {val_acc}')
# Out:
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9780 - loss: 0.0709
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9481 - loss: 0.1601
# train acc: 0.9769418835639954, validation acc: 0.9537299275398254

# %%
max_length = 0
for tokens in train['tokens']:
  if len(tokens) > max_length:
    max_length = len(tokens)
print(f'Maximum length of tokens: {max_length}')
# Out:
# Maximum length of tokens: 540

# %%
tokens_length = []
for tokens in train['tokens']:
  tokens_length.append(len(tokens))

mean_length = sum(tokens_length) / len(tokens_length)
print(f'Mean length of tokens: {mean_length}')
# Out:
# Mean length of tokens: 52.62264792564044

# %%
MAX_LEN = 300
vectorizer = keras.layers.TextVectorization(ngrams=2, output_sequence_length=MAX_LEN)
vectorizer.adapt(X_train)

# %%
VOCAB_SIZE = vectorizer.vocabulary_size()
EMBEDDING_DIM = 300

# %%
model = keras.Sequential()
model.add(vectorizer)
model.add(keras.layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM, name='embedding'))
model.add(keras.layers.LSTM(256, return_sequences=True, name='lstm', dropout=0.2, recurrent_dropout=0.2))
model.add(keras.layers.GlobalMaxPool1D())
model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.Dense(512, activation="relu"))
model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.Dense(11, activation='softmax'))

# %%
model.compile(
    loss = keras.losses.categorical_crossentropy,
    optimizer = keras.optimizers.Adam(learning_rate=0.01),
    metrics = ['accuracy']
)

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3, restore_best_weights=True)

history = model.fit(
    X_train, y_train_cat,
    batch_size=64,
    epochs=50,
    validation_data=(X_val, y_val_cat),
    callbacks=[early_stopping_cb],
    shuffle=True
)
# Out:
# Epoch 1/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 72s 568ms/step - accuracy: 0.6943 - loss: 0.9018 - val_accuracy: 0.9500 - val_loss: 0.1555
# Epoch 2/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 76s 518ms/step - accuracy: 0.9665 - loss: 0.1161 - val_accuracy: 0.9396 - val_loss: 0.2849
# Epoch 3/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 64s 529ms/step - accuracy: 0.9801 - loss: 0.0728 - val_accuracy: 0.9490 - val_loss: 0.2646
# Epoch 4/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 62s 510ms/step - accuracy: 0.9884 - loss: 0.0408 - val_accuracy: 0.9528 - val_loss: 0.3353
# Epoch 5/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 63s 517ms/step - accuracy: 0.9870 - loss: 0.0488 - val_accuracy: 0.9490 - val_loss: 0.3075
# Epoch 6/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 82s 518ms/step - accuracy: 0.9909 - loss: 0.0343 - val_accuracy: 0.9500 - val_loss: 0.3342
# Epoch 7/50
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 64s 522ms/step - accuracy: 0.9854 - loss: 0.0577 - val_accuracy: 0.9443 - val_loss: 0.5080

# %%
model.evaluate(X_val, y_val_cat)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.9493 - loss: 0.3925
# [0.33248162269592285, 0.9527856707572937]

# %%
submission = pd.DataFrame()
submission['cat_id'] = clf.predict(X_test_tfidf)
submission.head()
# Out:
#    cat_id
# 0       9
# 1       7
# 2       3
# 3      10
# 4       3

# %%
test_pred = model.predict(X_test)
submission = pd.DataFrame({'cat_id': np.argmax(test_pred, axis=1)})
submission.head()
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step
#    cat_id
# 0      10
# 1       7
# 2       3
# 3      10
# 4       3
